# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
geo_df = gpd.read_file('depto/depto.shp')
#geo_df.to_csv('geo_df.csv',index =False)
geo_df
# Out:
#    DPTO                                         NOMBRE_DPT          AREA  \
# 0    05                                          ANTIOQUIA  6.335186e+10
# 1    08                                          ATLANTICO  3.360765e+09
# 2    11                              SANTAFE DE BOGOTA D.C  1.650948e+09
# 3    13                                            BOLIVAR  2.614189e+10
# 4    15                                             BOYACA  2.335258e+10
# 5    17                                             CALDAS  7.558200e+09
# 6    18                                            CAQUETA  9.018087e+10
# 7    19                                              CAUCA  2.974279e+10
# 8    20                                              CESAR  2.297310e+10
# 9    23                                            CORDOBA  2.505949e+10
# 10   25                                       CUNDINAMARCA  2.280026e+10
# 11   27                                              CHOCO  4.683852e+10
# ...

# %%
geo_df.loc[27,'geometry']

# %%
print(geo_df.loc[10,'geometry'])
# Out:
# POLYGON ((972454.1142484014 1127161.97143714, 972519.6724330861 1126332.516287495, 972840.6483841698 1125945.322888108, 973538.2336522229 1124794.937660593, 973604.783174936 1124275.128254765, 973348.6737357901 1122174.119084915, 973038.0693013743 1121156.833975188, 974312.334845559 1120503.854509816, 975076.05987533 1119674.129125237, 975142.3849171723 1118524.016158226, 974177.3858585188 1116998.276752539, 973479.4144214093 1115406.103281657, 972271.0253147788 1114190.13341789, 971373.0697797358 1113560.164433291, 970730.398204288 1112985.407495916, 970608.2460567004 1112034.438253388, 971117.4449285419 1110873.048458851, 971505.0274757661 1109921.801474863, 972522.9411081019 1108251.498890529, 973541.9635615546 1107100.993796902, 974317.3502772449 1105430.823112952, 975081.1895730218 1104413.119782493, 976232.7677424044 1102488.509325237, 976553.3672948305 1100630.495932026, 976608.7367407962 1099414.060425349, 977827.4175327871 1098009.185619324, 979877.1894204721 1096338.6810736
# ...

# %%
geo_df.plot(figsize = (20,12))
#geo_df.plot(column = 'AREA',legend = True,cmap='Greens',figsize = (20,12))
plt.savefig('departamentos_colombia.svg', format='svg', dpi=1200,bbox_inches="tight")
plt.show()

# %%
geo_df = gpd.read_file('mpio/mpio.shp')
#geo_df.to_csv('geo_df.csv',index =False)
geo_df
# Out:
#               AREA      PERIMETER  WCOLGEN02_  WCOLGEN021 DPTO  \
# 0     7.516766e+09  475636.130236           2         566   44
# 1     1.624663e+09  195961.387498           5         564   44
# 2     1.779934e+09  272174.538806           6         563   44
# 3     3.109950e+09  267346.564817           7         559   44
# 4     1.999866e+09  198794.872346           8        1052   44
# ...            ...            ...         ...         ...  ...
# 1117  1.333941e+09  211788.556842        1122         361   05
# 1118  2.816016e+09  359760.445480        1123         287   27
# 1119  2.727328e+07   40602.945357           4         994   88
# 1120  1.293062e+06    5955.813895        1098         995   88
# 1121  2.103618e+07   25387.491250           3         995   88
#
#                                              NOMBRE_DPT MPIO  \
# 0                                            LA GUAJIRA  847
# 1                                            LA GUAJIRA  560
# ...

# %%
geo_df.plot(figsize = (20,12))
plt.savefig('municipios_colombia.svg', format='svg', dpi=1200,bbox_inches="tight")
plt.show()
